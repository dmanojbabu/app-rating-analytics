# %%
# !pip install ipython-sql

# %%
# %load_ext sql

# %%
# %sql postgresql://airflow:airflow@postgres/airflow

# %%
# %sql SELECT * FROM app_ratings
# Out:
#  * postgresql://airflow:***@postgres/airflow
# 10 rows affected.
# [('2021-04-07', 'android', 10, 20, 30, 40, 50, 150, 1050.0, 3.67, 3.67, 'Customer Rating Declined'),
#  ('2021-04-07', 'íos', 10, 20, 30, 40, 50, 150, 1050.0, 3.67, 3.67, 'Customer Rating Declined'),
#  ('2021-04-08', 'android', 10, 20, 30, 40, 50, 150, 1050.0, 3.67, 3.67, 'Customer Rating Declined'),
#  ('2021-04-08', 'íos', 10, 20, 30, 40, 50, 150, 1050.0, 3.67, 3.67, 'Customer Rating Declined'),
#  ('2021-04-09', 'android', 10, 20, 30, 40, 50, 150, 1050.0, 3.67, 3.67, 'Customer Rating Declined'),
#  ('2021-04-09', 'íos', 10, 20, 30, 40, 50, 150, 1050.0, 3.67, 3.67, 'Customer Rating Declined'),
#  ('2021-04-10', 'android', 10, 20, 30, 40, 50, 150, 1050.0, 3.67, 3.67, 'Customer Rating Declined'),
#  ('2021-04-10', 'íos', 10, 20, 30, 40, 50, 150, 1050.0, 3.67, 3.67, 'Customer Rating Declined'),
#  ('2021-04-11', 'android', 10, 20, 30, 40, 50, 150, 1050.0, 3.67, 3.67, 'Customer Rating Declined'),
# ...

# %%
pip install psycopg2-binary
