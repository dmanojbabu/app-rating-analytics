# %%
pip install boto3 awswrangler pandas numpy

# %%
import boto3
from botocore.client import Config
import awswrangler as wr
import pandas as pd

boto_session = boto3.Session(aws_access_key_id='AKIAIOSFODNN7EXAMPLE',
                    aws_secret_access_key='wJalrXUtnFEMI/K7MDENG/bPxRfiCYEXAMPLEKEY')
wr.config.s3_endpoint_url='http://minio1:9000'
wr.s3.does_object_exist(str("s3://rating-store/tweak1"), boto3_session=boto_session)
# Out:
# False

# %%
stage_df = wr.s3.read_json('s3://rating-store/2021-04-11',lines=True, boto3_session=boto_session)
stage_df = stage_df[['1','2','3','4','5','date','store']]

stage_df['date'] = stage_df['date'].dt.strftime('%Y-%m-%d')
stage_df["rating_date"] = stage_df["date"]
stage_df.set_index('date',inplace=True)

stage_df = stage_df.rename(columns={"1":"R1","2":"R2","3":"R3","4":"R4","5":"R5"})

#stage_df = stage_df.sort_values(by='date')
stage_df = stage_df.sort_index()
stage_df.head()
# Out:
#             R1  R2  R3  R4  R5    store rating_date
# date
# 2021-04-01  10  20  30  40  50      íos  2021-04-01
# 2021-04-01  10  20  30  40  50  android  2021-04-01
# 2021-04-02  10  20  30  40  50      íos  2021-04-02
# 2021-04-02  10  20  30  40  50  android  2021-04-02
# 2021-04-03  10  20  30  40  50      íos  2021-04-03

# %%
path = f"s3://rating-store/ratings-pq/"

wr.s3.to_parquet(
    df=stage_df,
    path=path,
    dataset=True,
    mode="overwrite_partitions",
    partition_cols=['rating_date','store'],
    boto3_session=boto_session
)
# Out:
# {'paths': ['s3://rating-store/ratings-pq/rating_date=2021-04-01/store=android/f56870f21a7546bc819768a607a0c01f.snappy.parquet',
#   's3://rating-store/ratings-pq/rating_date=2021-04-01/store=ios/f56870f21a7546bc819768a607a0c01f.snappy.parquet',
#   's3://rating-store/ratings-pq/rating_date=2021-04-02/store=android/f56870f21a7546bc819768a607a0c01f.snappy.parquet',
#   's3://rating-store/ratings-pq/rating_date=2021-04-02/store=ios/f56870f21a7546bc819768a607a0c01f.snappy.parquet',
#   's3://rating-store/ratings-pq/rating_date=2021-04-03/store=android/f56870f21a7546bc819768a607a0c01f.snappy.parquet',
#   's3://rating-store/ratings-pq/rating_date=2021-04-03/store=ios/f56870f21a7546bc819768a607a0c01f.snappy.parquet',
#   's3://rating-store/ratings-pq/rating_date=2021-04-04/store=android/f56870f21a7546bc819768a607a0c01f.snappy.parquet',
#   's3://rating-store/ratings-pq/rating_date=2021-04-04/store=ios/f56870f21a7546bc819768a607a0c01f.snappy.parquet',
#   's3://rating-store/ratings-pq/rating_date=2021-04-05/store=android/f56870f21a7546bc819768a607a0c01f.snappy.parquet',
#   's3://rating-store/ratings-pq/rating_date=2021-04-05/store=ios/f56870f21a7546bc819768a607a0c01f.snappy.parquet',
#   's3://rating-store/ratings-pq/rating_date=2021-04-06/store=android/f56870f21a7546bc819768a607a0c01f.snappy.parquet',
#   's3://rating-store/ratings-pq/rating_date=2021-04-06/store=ios/f56870f21a7546bc819768a607a0c01f.snappy.parquet',
#   's3://rating-store/ratings-pq/rating_date=2021-04-07/store=android/f56870f21a7546bc819768a607a0c01f.snappy.parquet',
#   's3://rating-store/ratings-pq/rating_date=2021-04-07/store=ios/f56870f21a7546bc819768a607a0c01f.snappy.parquet',
#   's3://rating-store/ratings-pq/rating_date=2021-04-08/store=android/f56870f21a7546bc819768a607a0c01f.snappy.parquet',
#   's3://rating-store/ratings-pq/rating_date=2021-04-08/store=ios/f56870f21a7546bc819768a607a0c01f.snappy.parquet',
#   's3://rating-store/ratings-pq/rating_date=2021-04-09/store=android/f56870f21a7546bc819768a607a0c01f.snappy.parquet',
#   's3://rating-store/ratings-pq/rating_date=2021-04-09/store=ios/f56870f21a7546bc819768a607a0c01f.snappy.parquet',
#   's3://rating-store/ratings-pq/rating_date=2021-04-10/store=android/f56870f21a7546bc819768a607a0c01f.snappy.parquet',
#   's3://rating-store/ratings-pq/rating_date=2021-04-10/store=ios/f56870f21a7546bc819768a607a0c01f.snappy.parquet',
#   's3://rating-store/ratings-pq/rating_date=2021-04-11/store=android/f56870f21a7546bc819768a607a0c01f.snappy.parquet',
#   's3://rating-store/ratings-pq/rating_date=2021-04-11/store=ios/f56870f21a7546bc819768a607a0c01f.snappy.parquet',
#   's3://rating-store/ratings-pq/rating_date=2021-04-12/store=android/f56870f21a7546bc819768a607a0c01f.snappy.parquet',
#   's3://rating-store/ratings-pq/rating_date=2021-04-12/store=ios/f56870f21a7546bc819768a607a0c01f.snappy.parquet',
#   's3://rating-store/ratings-pq/rating_date=2021-04-13/store=android/f56870f21a7546bc819768a607a0c01f.snappy.parquet',
#   's3://rating-store/ratings-pq/rating_date=2021-04-13/store=ios/f56870f21a7546bc819768a607a0c01f.snappy.parquet',
#   's3://rating-store/ratings-pq/rating_date=2021-04-14/store=android/f56870f21a7546bc819768a607a0c01f.snappy.parquet',
#   's3://rating-store/ratings-pq/rating_date=2021-04-14/store=ios/f56870f21a7546bc819768a607a0c01f.snappy.parquet',
#   's3://rating-store/ratings-pq/rating_date=2021-04-15/store=android/f56870f21a7546bc819768a607a0c01f.snappy.parquet',
#   's3://rating-store/ratings-pq/rating_date=2021-04-15/store=ios/f56870f21a7546bc819768a607a0c01f.snappy.parquet',
#   's3://rating-store/ratings-pq/rating_date=2021-04-16/store=android/f56870f21a7546bc819768a607a0c01f.snappy.parquet',
#   's3://rating-store/ratings-pq/rating_date=2021-04-16/store=ios/f56870f21a7546bc819768a607a0c01f.snappy.parquet',
#   's3://rating-store/ratings-pq/rating_date=2021-04-17/store=android/f56870f21a7546bc819768a607a0c01f.snappy.parquet',
#   's3://rating-store/ratings-pq/rating_date=2021-04-17/store=ios/f56870f21a7546bc819768a607a0c01f.snappy.parquet',
#   's3://rating-store/ratings-pq/rating_date=2021-04-18/store=android/f56870f21a7546bc819768a607a0c01f.snappy.parquet',
#   's3://rating-store/ratings-pq/rating_date=2021-04-18/store=ios/f56870f21a7546bc819768a607a0c01f.snappy.parquet',
#   's3://rating-store/ratings-pq/rating_date=2021-04-19/store=android/f56870f21a7546bc819768a607a0c01f.snappy.parquet',
#   's3://rating-store/ratings-pq/rating_date=2021-04-19/store=ios/f56870f21a7546bc819768a607a0c01f.snappy.parquet',
#   's3://rating-store/ratings-pq/rating_date=2021-04-20/store=android/f56870f21a7546bc819768a607a0c01f.snappy.parquet',
#   's3://rating-store/ratings-pq/rating_date=2021-04-20/store=ios/f56870f21a7546bc819768a607a0c01f.snappy.parquet'],
#  'partitions_values': {'s3://rating-store/ratings-pq/rating_date=2021-04-01/store=android/': ['2021-04-01',
#    'android'],
#   's3://rating-store/ratings-pq/rating_date=2021-04-01/store=ios/': ['2021-04-01',
#    'ios'],
#   's3://rating-store/ratings-pq/rating_date=2021-04-02/store=android/': ['2021-04-02',
#    'android'],
#   's3://rating-store/ratings-pq/rating_date=2021-04-02/store=ios/': ['2021-04-02',
#    'ios'],
#   's3://rating-store/ratings-pq/rating_date=2021-04-03/store=android/': ['2021-04-03',
#    'android'],
#   's3://rating-store/ratings-pq/rating_date=2021-04-03/store=ios/': ['2021-04-03',
#    'ios'],
#   's3://rating-store/ratings-pq/rating_date=2021-04-04/store=android/': ['2021-04-04',
#    'android'],
#   's3://rating-store/ratings-pq/rating_date=2021-04-04/store=ios/': ['2021-04-04',
#    'ios'],
#   's3://rating-store/ratings-pq/rating_date=2021-04-05/store=android/': ['2021-04-05',
#    'android'],
#   's3://rating-store/ratings-pq/rating_date=2021-04-05/store=ios/': ['2021-04-05',
#    'ios'],
#   's3://rating-store/ratings-pq/rating_date=2021-04-06/store=android/': ['2021-04-06',
#    'android'],
#   's3://rating-store/ratings-pq/rating_date=2021-04-06/store=ios/': ['2021-04-06',
#    'ios'],
#   's3://rating-store/ratings-pq/rating_date=2021-04-07/store=android/': ['2021-04-07',
#    'android'],
#   's3://rating-store/ratings-pq/rating_date=2021-04-07/store=ios/': ['2021-04-07',
#    'ios'],
#   's3://rating-store/ratings-pq/rating_date=2021-04-08/store=android/': ['2021-04-08',
#    'android'],
#   's3://rating-store/ratings-pq/rating_date=2021-04-08/store=ios/': ['2021-04-08',
#    'ios'],
#   's3://rating-store/ratings-pq/rating_date=2021-04-09/store=android/': ['2021-04-09',
#    'android'],
#   's3://rating-store/ratings-pq/rating_date=2021-04-09/store=ios/': ['2021-04-09',
#    'ios'],
#   's3://rating-store/ratings-pq/rating_date=2021-04-10/store=android/': ['2021-04-10',
#    'android'],
#   's3://rating-store/ratings-pq/rating_date=2021-04-10/store=ios/': ['2021-04-10',
#    'ios'],
#   's3://rating-store/ratings-pq/rating_date=2021-04-11/store=android/': ['2021-04-11',
#    'android'],
#   's3://rating-store/ratings-pq/rating_date=2021-04-11/store=ios/': ['2021-04-11',
#    'ios'],
#   's3://rating-store/ratings-pq/rating_date=2021-04-12/store=android/': ['2021-04-12',
#    'android'],
#   's3://rating-store/ratings-pq/rating_date=2021-04-12/store=ios/': ['2021-04-12',
#    'ios'],
#   's3://rating-store/ratings-pq/rating_date=2021-04-13/store=android/': ['2021-04-13',
#    'android'],
#   's3://rating-store/ratings-pq/rating_date=2021-04-13/store=ios/': ['2021-04-13',
#    'ios'],
#   's3://rating-store/ratings-pq/rating_date=2021-04-14/store=android/': ['2021-04-14',
#    'android'],
#   's3://rating-store/ratings-pq/rating_date=2021-04-14/store=ios/': ['2021-04-14',
#    'ios'],
#   's3://rating-store/ratings-pq/rating_date=2021-04-15/store=android/': ['2021-04-15',
#    'android'],
#   's3://rating-store/ratings-pq/rating_date=2021-04-15/store=ios/': ['2021-04-15',
#    'ios'],
#   's3://rating-store/ratings-pq/rating_date=2021-04-16/store=android/': ['2021-04-16',
#    'android'],
#   's3://rating-store/ratings-pq/rating_date=2021-04-16/store=ios/': ['2021-04-16',
#    'ios'],
#   's3://rating-store/ratings-pq/rating_date=2021-04-17/store=android/': ['2021-04-17',
#    'android'],
#   's3://rating-store/ratings-pq/rating_date=2021-04-17/store=ios/': ['2021-04-17',
#    'ios'],
#   's3://rating-store/ratings-pq/rating_date=2021-04-18/store=android/': ['2021-04-18',
#    'android'],
#   's3://rating-store/ratings-pq/rating_date=2021-04-18/store=ios/': ['2021-04-18',
#    'ios'],
#   's3://rating-store/ratings-pq/rating_date=2021-04-19/store=android/': ['2021-04-19',
#    'android'],
#   's3://rating-store/ratings-pq/rating_date=2021-04-19/store=ios/': ['2021-04-19',
#    'ios'],
#   's3://rating-store/ratings-pq/rating_date=2021-04-20/store=android/': ['2021-04-20',
#    'android'],
#   's3://rating-store/ratings-pq/rating_date=2021-04-20/store=ios/': ['2021-04-20',
#    'ios']}}
